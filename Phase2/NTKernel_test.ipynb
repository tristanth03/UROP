# %%
include("NTKernel.jl")
# Out:
# kernel (generic function with 1 method)

# %%
dummy = Chain(Dense(3=>3,sigmoid),Dense(3=>3))

X = [1 2 3; 1 2 3; 1 2 3]
Y = map_model(dummy,X)
# Out:
# 3-element Vector{Any}:
#  Float32[-0.0011008487, -0.0009613151, -0.0006753623, -0.00040855212, 0.0011762646, -0.005943848, -0.01030093, -0.0065419604, 0.008465383, -0.0022233597  …  -0.0002729221, -0.004360249, -0.003481752, -0.00019744504, -0.0020573079, 0.0033952475, 0.009335458, -0.00570371, 0.008849412, -0.00440485]
#  Float32[-0.0022840975, -0.0023414972, 0.0006333599, -0.0007892377, -0.0005949149, -0.006412877, -0.008097675, -0.003698538, 0.006802176, -0.004242473  …  -0.0024245325, -0.0032055965, -0.0021516406, 9.688898f-5, -0.0003496257, 0.0034972087, 0.0075251576, -0.0052811173, 0.008170937, -0.003082142]
#  Float32[-0.00297476, -0.0032924395, 0.0016325768, -0.0013726298, -0.002034877, -0.0067819594, -0.006631606, -0.0017254056, 0.0056986306, -0.0055058273  …  -0.003807028, -0.002384691, -0.001212557, 0.00058944966, 0.0009627086, 0.003489757, 0.0064818608, -0.0051212306, 0.0076491055, -0.002052346]
